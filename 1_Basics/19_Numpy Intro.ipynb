# %% [markdown]
# # Numpy Intro

# %%
import pandas as pd
import random

salary_list = [random.randint(50_000, 100_000) for _ in range(1_000_000)]
salary_list

# creating fake salary list
# Out:
# [50576,
#  77134,
#  95102,
#  89708,
#  68245,
#  82569,
#  53985,
#  77015,
#  71820,
#  50341,
#  78769,
#  94231,
#  90115,
#  55662,
#  69207,
#  85136,
#  61732,
#  72040,
#  50052,
#  65069,
#  78445,
#  99859,
#  80274,
#  76037,
#  55723,
#  83858,
#  82864,
#  70539,
#  65549,
#  96299,
#  72915,
#  60982,
#  98229,
#  55606,
#  96746,
#  72197,
#  81422,
#  56303,
#  87510,
#  97516,
#  94999,
#  99360,
#  78667,
#  92609,
#  56054,
#  86765,
#  73022,
#  79876,
#  59549,
#  85109,
#  72149,
#  83223,
#  50131,
#  67492,
#  55579,
#  87198,
#  64903,
#  85149,
#  94095,
#  79921,
#  77643,
#  76486,
#  80052,
#  76469,
#  70315,
#  64727,
#  82956,
#  63993,
#  94436,
#  79973,
#  84665,
#  57643,
#  68093,
#  50944,
#  51441,
#  91120,
#  63851,
#  76083,
#  65103,
#  73892,
#  76144,
#  88707,
#  61406,
#  98879,
#  75251,
#  98476,
#  50223,
#  93781,
#  88050,
#  55695,
#  80446,
#  59937,
#  75416,
#  98035,
#  86413,
#  53402,
#  53573,
#  57153,
#  78017,
#  53778,
# ...

# %%
# %%timeit

statistics.mean(salary_list)
# Out:
# 408 ms ± 1.44 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import numpy as np

# %%
# %%timeit
np.mean(salary_list)

# can see the difference in speed using the numpy versions
# which when working with extremely large datasets a faster run time is going to be nice
# Out:
# 58 ms ± 2.32 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
print('Median: ', np.median(salary_list))
print('Minimum: ', np.min(salary_list))
print('Maximum: ', np.max(salary_list))
# Out:
# Median:  75013.5
# Minimum:  50000
# Maximum:  100000

# %%
# Creating Arrays for use case scenarios

# Job Titles
job_titles = np.array(['Data Analyst', 'Data Scientist', 'Data Engineer', 'Machine Learning Engineer', 'AI Engineer'])

# Base Salaries
base_salaries = np.array([60000, 80000, 75000, 90000, np.nan])

# Bonus Rates
bonus_rates = np.array([.05, .1, .08, .12, np.nan])

# np.nan replaces the None type allowing calculations to be still be performed

# %%
total_salaries = base_salaries * (1 + bonus_rates)

total_salaries
# Out:
# array([ 63000.,  88000.,  81000., 100800.,     nan])

# %%
np.nanmean(total_salaries)

# np.nanmean replaces np.mean when there are nan values present
# nan = not a number
# Out:
# 83200.0
